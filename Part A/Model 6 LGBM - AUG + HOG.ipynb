# %% [markdown]
# # Model 3: LGBM - AUG + HOG

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from lightgbm import LGBMClassifier
from functions import train_predict_ml, cross_validation

# %%
lgbm = LGBMClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_hog.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_hog.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  83.2167 %
# Test Accuracy Score   :  60.2500 %
# Training Time         :  103.4120
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.67      0.66      0.66      1000
#   Automobile       0.70      0.74      0.72      1000
#         Bird       0.54      0.45      0.49      1000
#          Cat       0.46      0.39      0.42      1000
#         Deer       0.52      0.57      0.55      1000
#          Dog       0.48      0.49      0.48      1000
#         Frog       0.61      0.70      0.65      1000
#        Horse       0.66      0.66      0.66      1000
#         Ship       0.65      0.67      0.66      1000
#        Truck       0.71      0.71      0.71      1000
#
#     accuracy                           0.60     10000
#    macro avg       0.60      0.60      0.60     10000
# weighted avg       0.60      0.60      0.60     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.59816667 0.602      0.6025     0.59458333 0.52358333]
# Mean: 0.5841666666666667
# Standard Deviation: 0.030426916081361634
# Training Time: 427.9461929798126
