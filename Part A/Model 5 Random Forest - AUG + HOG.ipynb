# %% [markdown]
# # Model 5: Random Forest - AUG + HOG

# %%
from sklearn.ensemble import RandomForestClassifier
from functions import cross_validation
from functions import train_predict_ml

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(rf, data_train="../Data/train_aug_hog.csv", data_test="../Data/test_hog.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  100.0000 %
# Test Accuracy Score   :  52.6300 %
# Training Time         :  237.1816
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.64      0.61      0.62      1000
#   Automobile       0.57      0.69      0.62      1000
#         Bird       0.46      0.34      0.39      1000
#          Cat       0.37      0.26      0.31      1000
#         Deer       0.45      0.46      0.46      1000
#          Dog       0.42      0.48      0.44      1000
#         Frog       0.51      0.65      0.57      1000
#        Horse       0.61      0.57      0.59      1000
#         Ship       0.61      0.60      0.60      1000
#        Truck       0.59      0.61      0.60      1000
#
#     accuracy                           0.53     10000
#    macro avg       0.52      0.53      0.52     10000
# weighted avg       0.52      0.53      0.52     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
rf2 = RandomForestClassifier(random_state=42)

# %%
cross_validation(rf2, data_train="../Data/train_aug_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.51941667 0.52675    0.52566667 0.52341667 0.47616667]
# Mean: 0.5142833333333334
# Standard Deviation: 0.019223148661040003
# Training Time: 618.0780804157257
