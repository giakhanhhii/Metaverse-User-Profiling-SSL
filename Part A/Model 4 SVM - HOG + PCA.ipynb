# %% [markdown]
# # Model 4: SVM - HOG + PCA

# %%
from sklearn import svm
from functions import cross_validation
from functions import train_predict_ml

# %%
svc=svm.SVC(random_state=42,probability=True)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(svc, data_train="../Data/train_hog_pca.csv", data_test="../Data/test_hog_pca.csv")
# Out:
# Accuracy Score:
# ============================
# Train Accuracy Score  :  82.9660 %
# Test Accuracy Score   :  65.5600 %
# Training Time         :  9409.0568
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.69      0.75      0.72      1000
#   Automobile       0.78      0.79      0.78      1000
#         Bird       0.57      0.52      0.55      1000
#          Cat       0.48      0.45      0.47      1000
#         Deer       0.59      0.64      0.61      1000
#          Dog       0.54      0.53      0.53      1000
#         Frog       0.69      0.75      0.72      1000
#        Horse       0.72      0.68      0.70      1000
#         Ship       0.72      0.71      0.71      1000
#        Truck       0.75      0.75      0.75      1000
#
#     accuracy                           0.66     10000
#    macro avg       0.65      0.66      0.65     10000
# weighted avg       0.65      0.66      0.65     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Automobile', 'Airplane', 'Cat', 'Frog', 'Frog', 'Frog', 'Cat', 'Automobile']

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(svc, data_train="../Data/train_hog_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.6474 0.6442 0.6466 0.6466 0.6535]
# Mean: 0.6476599999999999
# Standard Deviation: 0.0031110126968561186
# Training Time: 17540.49812436104
