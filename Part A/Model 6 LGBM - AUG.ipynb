# %% [markdown]
# # Model 3: LGBM - AUG

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from lightgbm import LGBMClassifier
from functions import train_predict_ml, cross_validation

# %%
lgbm = LGBMClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug.csv")
# Out:
# ...
# 170498071/170498071 [==============================] - 11s 0us/step
# Accuracy Score:
# ...
# Train Accuracy Score  :  85.2283%
# Test Accuracy Score   :  53.3000%
# Training Time         :  1558.5789
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.61      0.61      0.61      1000
#   Automobile       0.63      0.64      0.64      1000
#         Bird       0.42      0.39      0.40      1000
#          Cat       0.40      0.35      0.37      1000
#         Deer       0.47      0.41      0.43      1000
#          Dog       0.44      0.45      0.45      1000
#         Frog       0.53      0.64      0.58      1000
#        Horse       0.58      0.55      0.56      1000
#         Ship       0.65      0.68      0.66      1000
#        Truck       0.57      0.61      0.59      1000
#
#     accuracy                           0.53     10000
#    macro avg       0.53      0.53      0.53     10000
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.53525    0.53266667 0.54025    0.53066667 0.50975   ]
# Mean: 0.5297166666666666
# Standard Deviation: 0.010486578723937231
# Training Time: 6820.510156869888
