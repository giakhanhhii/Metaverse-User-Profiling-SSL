# %% [markdown]
# # Model 5: Random Forest - AUG + PCA

# %%
from sklearn.ensemble import RandomForestClassifier
from functions import cross_validation
from functions import train_predict_ml

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(rf, data_train="../Data/train_aug_pca.csv", data_test="../Data/test_aug_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  100.0000 %
# Test Accuracy Score   :  40.1200 %
# Training Time         :  246.6204
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.46      0.52      0.49      1000
#   Automobile       0.42      0.55      0.47      1000
#         Bird       0.30      0.26      0.28      1000
#          Cat       0.28      0.23      0.25      1000
#         Deer       0.37      0.32      0.34      1000
#          Dog       0.34      0.33      0.34      1000
#         Frog       0.44      0.45      0.45      1000
#        Horse       0.41      0.35      0.37      1000
#         Ship       0.53      0.54      0.54      1000
#        Truck       0.41      0.46      0.43      1000
#
#     accuracy                           0.40     10000
#    macro avg       0.40      0.40      0.40     10000
# weighted avg       0.40      0.40      0.40     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
rf2 = RandomForestClassifier(random_state=42)

# %%
cross_validation(rf2, data_train="../Data/train_aug_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.39833333 0.38766667 0.38866667 0.38916667 0.38141667]
# Mean: 0.38905
# Standard Deviation: 0.005413357963819162
# Training Time: 918.8726811408997
