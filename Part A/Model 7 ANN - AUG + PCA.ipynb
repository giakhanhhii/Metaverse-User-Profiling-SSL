# %% [markdown]
# # Model 7: ANN

# %%
import tensorflow as tf
from functions import ann, train_predict_nn

# %%
ann = ann((633, ))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train-test split and make prediction (AUG + PCA Preprocessed Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, data_train='../Data/train_aug_pca.csv',
                data_test='../Data/test_aug_pca.csv')
# Out:
# Epoch 1/20
# 329/329 [==============================] - 3s 6ms/step - loss: 1.6509 - accuracy: 0.4144 - val_loss: 1.5399 - val_accuracy: 0.4558
# Epoch 2/20
# 329/329 [==============================] - 2s 5ms/step - loss: 1.2917 - accuracy: 0.5510 - val_loss: 1.4671 - val_accuracy: 0.4885
# Epoch 3/20
# 329/329 [==============================] - 2s 6ms/step - loss: 1.0471 - accuracy: 0.6364 - val_loss: 1.4447 - val_accuracy: 0.5068
# Epoch 4/20
# 329/329 [==============================] - 2s 5ms/step - loss: 0.8288 - accuracy: 0.7099 - val_loss: 1.5418 - val_accuracy: 0.4972
# Epoch 5/20
# 329/329 [==============================] - 2s 6ms/step - loss: 0.6227 - accuracy: 0.7842 - val_loss: 1.6776 - val_accuracy: 0.5054
# Epoch 6/20
# 329/329 [==============================] - 3s 8ms/step - loss: 0.4428 - accuracy: 0.8503 - val_loss: 1.8599 - val_accuracy: 0.5044
# Epoch 7/20
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
