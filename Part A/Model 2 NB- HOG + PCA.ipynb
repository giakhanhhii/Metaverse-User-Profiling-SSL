# %% [markdown]
# # Model 2: NB - HOG + PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from sklearn.naive_bayes import GaussianNB
from functions import train_predict_ml, cross_validation

# %%
gnb = GaussianNB()

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_hog_pca.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_hog_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  49.5500 %
# Test Accuracy Score   :  49.3400 %
# Training Time         :  0.1478
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.53      0.44      0.48      1000
#   Automobile       0.64      0.55      0.59      1000
#         Bird       0.42      0.33      0.37      1000
#          Cat       0.33      0.46      0.38      1000
#         Deer       0.41      0.52      0.46      1000
#          Dog       0.46      0.38      0.41      1000
#         Frog       0.57      0.63      0.60      1000
#        Horse       0.61      0.48      0.54      1000
#         Ship       0.45      0.58      0.50      1000
#        Truck       0.68      0.56      0.61      1000
#
#     accuracy                           0.49     10000
#    macro avg       0.51      0.49      0.50     10000
# weighted avg       0.51      0.49      0.50     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_hog_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.491  0.4816 0.4908 0.4842 0.4906]
# Mean: 0.48764
# Standard Deviation: 0.003958585605996165
# Training Time: 0.7629375457763672
