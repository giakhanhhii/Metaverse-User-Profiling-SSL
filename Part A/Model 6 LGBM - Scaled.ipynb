# %% [markdown]
# # Model 3: LGBM - Scaled

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from lightgbm import LGBMClassifier
from functions import train_predict_ml, cross_validation

# %%
lgbm = LGBMClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction (original dataset with scaling)

# %%
train_predict_ml(lgbm, scale=1)
# Out:
# Accuracy Score:
# ============================
# Train Accuracy Score  :  88.8900 %
# Test Accuracy Score   :  53.1100 %
# Training Time         :  1464.0067
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.59      0.61      0.60      1000
#   Automobile       0.65      0.64      0.64      1000
#         Bird       0.42      0.38      0.40      1000
#          Cat       0.37      0.35      0.36      1000
#         Deer       0.46      0.42      0.44      1000
#          Dog       0.46      0.44      0.45      1000
#         Frog       0.53      0.64      0.58      1000
#        Horse       0.59      0.56      0.57      1000
#         Ship       0.63      0.67      0.65      1000
#        Truck       0.57      0.61      0.59      1000
#
#     accuracy                           0.53     10000
#    macro avg       0.53      0.53      0.53     10000
# weighted avg       0.53      0.53      0.53     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Bird', 'Frog', 'Cat', 'Frog', 'Dog', 'Ship']

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(lgbm, scale=1)
# Out:
# Model Accuracies:
# Individual Accuracy: [0.5313 0.5228 0.5347 0.5224 0.5256]
# Mean: 0.52736
# Standard Deviation: 0.004855759466859932
# Training Time: 6456.958110332489
