# %% [markdown]
# # Model 8: CNN - AUG

# %%
from functions import cnn
from functions import train_predict_nn
from tensorflow.keras.utils import plot_model

# %%
cnn = cnn((32,32,3))
cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# cnn.summary()

# %% [markdown]
# ### Train-test split and make prediction (Orginal dataset without scaling)

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_predict_nn(cnn, clf_name="CNN", data_train="/content/drive/MyDrive/Colab Notebooks/train_aug.csv", epochs=15, flatten=0)
# Out:
# Epoch 1/15
# 1313/1313 [==============================] - 25s 11ms/step - loss: 1.6959 - accuracy: 0.3909 - val_loss: 1.6595 - val_accuracy: 0.4512
# Epoch 2/15
# 1313/1313 [==============================] - 13s 10ms/step - loss: 1.2061 - accuracy: 0.5734 - val_loss: 1.1123 - val_accuracy: 0.6103
# Epoch 3/15
# 1313/1313 [==============================] - 13s 10ms/step - loss: 1.0556 - accuracy: 0.6327 - val_loss: 1.0491 - val_accuracy: 0.6404
# Epoch 4/15
# 1313/1313 [==============================] - 13s 10ms/step - loss: 0.9308 - accuracy: 0.6786 - val_loss: 1.0104 - val_accuracy: 0.6599
# Epoch 5/15
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.8450 - accuracy: 0.7085 - val_loss: 0.8475 - val_accuracy: 0.7072
# Epoch 6/15
# 1313/1313 [==============================] - 13s 10ms/step - loss: 0.7657 - accuracy: 0.7377 - val_loss: 1.2266 - val_accuracy: 0.6032
# Epoch 7/15
# ...

# %% [markdown]
# ### Cross-validation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# N/A
