# %% [markdown]
# # Model 5: Random Forest - AUG

# %%
from sklearn.ensemble import RandomForestClassifier
from functions import cross_validation
from functions import train_predict_ml

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(rf, data_train="../Data/train_aug.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  100.0000%
# Test Accuracy Score   :  47.2500%
# Training Time         :  303.7856
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.54      0.57      0.56      1000
#   Automobile       0.51      0.55      0.53      1000
#         Bird       0.38      0.33      0.35      1000
#          Cat       0.35      0.30      0.32      1000
#         Deer       0.39      0.37      0.38      1000
#          Dog       0.42      0.41      0.41      1000
#         Frog       0.46      0.54      0.50      1000
#        Horse       0.53      0.46      0.49      1000
#         Ship       0.59      0.62      0.61      1000
#        Truck       0.50      0.57      0.53      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.47      0.47      0.47     10000
# weighted avg       0.47      0.47      0.47     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
rf2= RandomForestClassifier(random_state=42)

# %%
cross_validation(rf2, data_train="../Data/train_aug.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.47266667 0.46808333 0.46533333 0.46566667 0.46      ]
# Mean: 0.46635
# Standard Deviation: 0.004116497972252088
# Training Time: 2302.3322134017944
