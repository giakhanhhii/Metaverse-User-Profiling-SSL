# %% [markdown]
# # Model 5: Random Forest - HOG

# %%
from sklearn.ensemble import RandomForestClassifier
from functions import cross_validation
from functions import train_predict_ml

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(rf, data_train="../Data/train_hog.csv", data_test="../Data/test_hog.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  100.0000 %
# Test Accuracy Score   :  52.9100 %
# Training Time         :  216.6853
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.62      0.63      0.62      1000
#   Automobile       0.58      0.68      0.63      1000
#         Bird       0.47      0.36      0.41      1000
#          Cat       0.36      0.29      0.32      1000
#         Deer       0.45      0.46      0.45      1000
#          Dog       0.40      0.44      0.42      1000
#         Frog       0.54      0.68      0.60      1000
#        Horse       0.60      0.54      0.57      1000
#         Ship       0.62      0.60      0.61      1000
#        Truck       0.60      0.62      0.61      1000
#
#     accuracy                           0.53     10000
#    macro avg       0.53      0.53      0.52     10000
# weighted avg       0.53      0.53      0.52     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
rf2 = RandomForestClassifier(random_state=42)

# %%
cross_validation(rf2, data_train="../Data/train_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.5219 0.5241 0.5214 0.515  0.5267]
# Mean: 0.5218200000000001
# Standard Deviation: 0.0038912208881018142
# Training Time: 786.5215182304382
