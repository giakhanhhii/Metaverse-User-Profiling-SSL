# %% [markdown]
# # Model 2: NB - AUG + HOG

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from sklearn.naive_bayes import GaussianNB
from functions import train_predict_ml, cross_validation

# %%
gnb = GaussianNB()

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_hog.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_hog.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  45.8233 %
# Test Accuracy Score   :  46.9400 %
# Training Time         :  0.3734
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.55      0.44      0.49      1000
#   Automobile       0.47      0.52      0.50      1000
#         Bird       0.41      0.32      0.36      1000
#          Cat       0.39      0.25      0.31      1000
#         Deer       0.44      0.36      0.39      1000
#          Dog       0.37      0.52      0.43      1000
#         Frog       0.47      0.65      0.55      1000
#        Horse       0.58      0.46      0.51      1000
#         Ship       0.47      0.58      0.52      1000
#        Truck       0.58      0.59      0.58      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.47      0.47      0.46     10000
# weighted avg       0.47      0.47      0.46     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.46533333 0.46441667 0.46841667 0.45908333 0.41858333]
# Mean: 0.4551666666666666
# Standard Deviation: 0.018537349684713118
# Training Time: 3.4959428310394287
