# %% [markdown]
# # Model 7: ANN

# %%
import tensorflow as tf
from functions import ann, train_predict_nn

# %%
ann = ann((324, ))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train-test split and make prediction (AUG + HOG Preprocessed Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, data_train='../Data/train_aug_hog.csv',
                data_test='../Data/test_hog.csv')
# Out:
# Epoch 1/20
# 329/329 [==============================] - 2s 5ms/step - loss: 1.5880 - accuracy: 0.4343 - val_loss: 1.4968 - val_accuracy: 0.4728
# Epoch 2/20
# 329/329 [==============================] - 1s 4ms/step - loss: 1.2977 - accuracy: 0.5440 - val_loss: 1.4363 - val_accuracy: 0.4932
# Epoch 3/20
# 329/329 [==============================] - 1s 4ms/step - loss: 1.1938 - accuracy: 0.5837 - val_loss: 1.3850 - val_accuracy: 0.5257
# Epoch 4/20
# 329/329 [==============================] - 1s 4ms/step - loss: 1.1177 - accuracy: 0.6098 - val_loss: 1.3213 - val_accuracy: 0.5416
# Epoch 5/20
# 329/329 [==============================] - 1s 4ms/step - loss: 1.0576 - accuracy: 0.6297 - val_loss: 1.2837 - val_accuracy: 0.5578
# Epoch 6/20
# 329/329 [==============================] - 1s 4ms/step - loss: 1.0046 - accuracy: 0.6488 - val_loss: 1.2569 - val_accuracy: 0.5651
# Epoch 7/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.9609 - accuracy: 0.6635 - val_loss: 1.2628 - val_accuracy: 0.5626
# Epoch 8/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.9142 - accuracy: 0.6810 - val_loss: 1.2656 - val_accuracy: 0.5655
# Epoch 9/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.8652 - accuracy: 0.6998 - val_loss: 1.2878 - val_accuracy: 0.5698
# Epoch 10/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.8323 - accuracy: 0.7104 - val_loss: 1.2906 - val_accuracy: 0.5771
# Epoch 11/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.7874 - accuracy: 0.7254 - val_loss: 1.3098 - val_accuracy: 0.5670
# Epoch 12/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.7423 - accuracy: 0.7380 - val_loss: 1.3011 - val_accuracy: 0.5761
# Epoch 13/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.7040 - accuracy: 0.7530 - val_loss: 1.3310 - val_accuracy: 0.5773
# Epoch 14/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.6633 - accuracy: 0.7669 - val_loss: 1.3377 - val_accuracy: 0.5781
# Epoch 15/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.6219 - accuracy: 0.7821 - val_loss: 1.4633 - val_accuracy: 0.5559
# Epoch 16/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.5796 - accuracy: 0.7970 - val_loss: 1.4417 - val_accuracy: 0.5717
# Epoch 17/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.5378 - accuracy: 0.8106 - val_loss: 1.4728 - val_accuracy: 0.5720
# Epoch 18/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4920 - accuracy: 0.8274 - val_loss: 1.5472 - val_accuracy: 0.5694
# Epoch 19/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4492 - accuracy: 0.8401 - val_loss: 1.6382 - val_accuracy: 0.5702
# Epoch 20/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4081 - accuracy: 0.8573 - val_loss: 1.6804 - val_accuracy: 0.5603
# Accuracy Score:
# ============================
# Train Accuracy Score  :  78.7283%
# Test Accuracy Score   :  61.4300%
# Training Time         :  25.6556
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.65      0.69      0.67      1000
#   Automobile       0.73      0.80      0.76      1000
#         Bird       0.48      0.58      0.53      1000
#          Cat       0.44      0.34      0.38      1000
#         Deer       0.60      0.48      0.54      1000
#          Dog       0.47      0.53      0.49      1000
#         Frog       0.67      0.66      0.66      1000
#        Horse       0.69      0.65      0.67      1000
#         Ship       0.68      0.68      0.68      1000
#        Truck       0.73      0.73      0.73      1000
#
#     accuracy                           0.61     10000
#    macro avg       0.61      0.61      0.61     10000
# weighted avg       0.61      0.61      0.61     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Automobile', 'Airplane', 'Frog', 'Deer', 'Frog', 'Frog', 'Cat', 'Frog']

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
