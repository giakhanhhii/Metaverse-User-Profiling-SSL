# %% [markdown]
# # Model 7: ANN

# %%
import tensorflow as tf
from functions import ann, train_predict_nn

# %%
ann = ann((658, ))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train-test split and make prediction (PCA Preprocessed Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, data_train='../Data/train_pca.csv', 
                data_test='../Data/test_pca.csv')
# Out:
# Epoch 1/20
# 274/274 [==============================] - 2s 6ms/step - loss: 1.7297 - accuracy: 0.3829 - val_loss: 1.5493 - val_accuracy: 0.4575
# Epoch 2/20
# 274/274 [==============================] - 1s 5ms/step - loss: 1.3417 - accuracy: 0.5303 - val_loss: 1.4484 - val_accuracy: 0.4930
# Epoch 3/20
# 274/274 [==============================] - 1s 5ms/step - loss: 1.1002 - accuracy: 0.6124 - val_loss: 1.4343 - val_accuracy: 0.5102
# Epoch 4/20
# 274/274 [==============================] - 1s 4ms/step - loss: 0.8720 - accuracy: 0.6928 - val_loss: 1.4967 - val_accuracy: 0.5176
# Epoch 5/20
# 274/274 [==============================] - 1s 5ms/step - loss: 0.6564 - accuracy: 0.7737 - val_loss: 1.6359 - val_accuracy: 0.5094
# Epoch 6/20
# 274/274 [==============================] - 1s 4ms/step - loss: 0.4629 - accuracy: 0.8409 - val_loss: 1.8978 - val_accuracy: 0.5101
# Epoch 7/20
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
