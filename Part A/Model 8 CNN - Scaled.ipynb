# %% [markdown]
# # Model 8: CNN - Scaled

# %%
from functions import cnn
from functions import train_predict_nn
from tensorflow.keras.utils import plot_model

# %%
cnn = cnn((32,32,3))
cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#cnn.summary()

# %% [markdown]
# ### Train-test split and make prediction (with scaling)

# %%
train_predict_nn(cnn, clf_name="CNN", epochs=15,flatten=0)
# Out:
# Epoch 1/15
# 1094/1094 [==============================] - 106s 96ms/step - loss: 1.6473 - accuracy: 0.4005 - val_loss: 1.2283 - val_accuracy: 0.5538
# Epoch 2/15
# 1094/1094 [==============================] - 120s 109ms/step - loss: 1.1890 - accuracy: 0.5711 - val_loss: 1.1211 - val_accuracy: 0.5919
# Epoch 3/15
# 1094/1094 [==============================] - 121s 110ms/step - loss: 1.0084 - accuracy: 0.6512 - val_loss: 0.8558 - val_accuracy: 0.6973
# Epoch 4/15
# 1094/1094 [==============================] - 118s 108ms/step - loss: 0.8863 - accuracy: 0.6938 - val_loss: 0.8101 - val_accuracy: 0.7128
# Epoch 5/15
# 1094/1094 [==============================] - 129s 118ms/step - loss: 0.8109 - accuracy: 0.7221 - val_loss: 0.7930 - val_accuracy: 0.7239
# Epoch 6/15
# 1094/1094 [==============================] - 128s 117ms/step - loss: 0.7383 - accuracy: 0.7457 - val_loss: 0.7194 - val_accuracy: 0.7568
# Epoch 7/15
# 1094/1094 [==============================] - 127s 116ms/step - loss: 0.6808 - accuracy: 0.7656 - val_loss: 0.7405 - val_accuracy: 0.7474
# Epoch 8/15
# 1094/1094 [==============================] - 127s 116ms/step - loss: 0.6340 - accuracy: 0.7843 - val_loss: 0.6953 - val_accuracy: 0.7761
# Epoch 9/15
# 1094/1094 [==============================] - 129s 118ms/step - loss: 0.5911 - accuracy: 0.7960 - val_loss: 0.7245 - val_accuracy: 0.7540
# Epoch 10/15
# 1094/1094 [==============================] - 126s 116ms/step - loss: 0.5514 - accuracy: 0.8114 - val_loss: 0.6247 - val_accuracy: 0.7941
# Epoch 11/15
# 1094/1094 [==============================] - 125s 114ms/step - loss: 0.5258 - accuracy: 0.8173 - val_loss: 0.6582 - val_accuracy: 0.7874
# Epoch 12/15
# 1094/1094 [==============================] - 126s 115ms/step - loss: 0.4928 - accuracy: 0.8290 - val_loss: 0.6154 - val_accuracy: 0.8000
# Epoch 13/15
# 1094/1094 [==============================] - 125s 115ms/step - loss: 0.4744 - accuracy: 0.8373 - val_loss: 0.6237 - val_accuracy: 0.8047
# Epoch 14/15
# 1094/1094 [==============================] - 127s 116ms/step - loss: 0.4427 - accuracy: 0.8471 - val_loss: 0.5825 - val_accuracy: 0.8107
# Epoch 15/15
# 1094/1094 [==============================] - 122s 111ms/step - loss: 0.4208 - accuracy: 0.8547 - val_loss: 0.6100 - val_accuracy: 0.8101
# Accuracy Score:
# ============================
# Train Accuracy Score  :  88.7040%
# Test Accuracy Score   :  80.8800%
# Training Time         :  1856.4790
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.80      0.83      0.81      1000
#   Automobile       0.89      0.93      0.91      1000
#         Bird       0.73      0.71      0.72      1000
#          Cat       0.64      0.68      0.66      1000
#         Deer       0.84      0.76      0.80      1000
#          Dog       0.70      0.74      0.72      1000
#         Frog       0.89      0.85      0.87      1000
#        Horse       0.91      0.77      0.83      1000
#         Ship       0.86      0.91      0.88      1000
#        Truck       0.86      0.92      0.89      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Automobile', 'Automobile', 'Ship', 'Frog', 'Dog', 'Automobile', 'Frog', 'Cat', 'Automobile']

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A
