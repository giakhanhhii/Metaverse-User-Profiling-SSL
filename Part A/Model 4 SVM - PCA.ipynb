# %% [markdown]
# # Model 4: SVM- PCA

# %%
from sklearn import svm
from functions import cross_validation
from functions import train_predict_ml

# %%
svc=svm.SVC(random_state=42,probability=True)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(svc, data_train="../Data/train_pca.csv", data_test="../Data/test_pca.csv")
# Out:
# Accuracy Score:
# ============================
# Train Accuracy Score  :  70.1560 %
# Test Accuracy Score   :  54.4400 %
# Training Time         :  23716.6155
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.61      0.62      0.62      1000
#   Automobile       0.64      0.64      0.64      1000
#         Bird       0.42      0.41      0.41      1000
#          Cat       0.38      0.38      0.38      1000
#         Deer       0.47      0.44      0.46      1000
#          Dog       0.49      0.43      0.46      1000
#         Frog       0.54      0.65      0.59      1000
#        Horse       0.64      0.57      0.60      1000
#         Ship       0.65      0.69      0.67      1000
#        Truck       0.59      0.62      0.60      1000
#
#     accuracy                           0.54     10000
#    macro avg       0.54      0.54      0.54     10000
# weighted avg       0.54      0.54      0.54     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Deer', 'Frog', 'Cat', 'Frog', 'Bird', 'Automobile']

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(svc, data_train="../Data/train_pca.csv")
