# %% [markdown]
# # Model 1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from functions import train_predict_ml, cross_validation

# %% [markdown]
# ### Train-test split and make prediction (AUG + HOG + PCA Preprocessed Dataset)

# %%
lr = LogisticRegression(random_state=42)

# %%
train_predict_ml(lr, data_train="../Data/train_aug_hog_pca.csv", data_test="../Data/test_aug_hog_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  51.6533%
# Test Accuracy Score   :  52.1100%
# Training Time         :  2.9210
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.59      0.58      0.59      1000
#   Automobile       0.58      0.62      0.60      1000
#         Bird       0.45      0.38      0.42      1000
#          Cat       0.39      0.28      0.33      1000
#         Deer       0.46      0.43      0.45      1000
#          Dog       0.45      0.43      0.44      1000
#         Frog       0.51      0.67      0.58      1000
#        Horse       0.57      0.59      0.58      1000
#         Ship       0.54      0.54      0.54      1000
#        Truck       0.62      0.67      0.64      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.52      0.52      0.52     10000
# weighted avg       0.52      0.52      0.52     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
lr_cv = LogisticRegression(random_state=42)

# %%
cross_validation(lr_cv, data_train="../Data/train_aug_hog_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.52083333 0.51833333 0.52008333 0.52175    0.44741667]
# Mean: 0.5056833333333334
# Standard Deviation: 0.029154921444662554
# Training Time: 11.345886707305908
