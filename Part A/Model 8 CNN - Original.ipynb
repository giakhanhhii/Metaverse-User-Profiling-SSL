# %% [markdown]
# # Model 8: CNN - Original dataset

# %%
from functions import cnn
from functions import train_predict_nn
from tensorflow.keras.utils import plot_model

# %%
cnn = cnn((32,32,3))
cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 552,362
# Trainable params: 551,466
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ### Train-test split and make prediction (Orginal dataset without scaling)

# %%
train_predict_nn(cnn, clf_name="CNN", epochs=15,scale=0,flatten=0)
# Out:
# Epoch 1/15
# 1094/1094 [==============================] - 120s 109ms/step - loss: 1.6567 - accuracy: 0.4059 - val_loss: 1.5584 - val_accuracy: 0.4739
# Epoch 2/15
# 1094/1094 [==============================] - 125s 114ms/step - loss: 1.2124 - accuracy: 0.5686 - val_loss: 1.1373 - val_accuracy: 0.6005
# Epoch 3/15
# 1094/1094 [==============================] - 128s 117ms/step - loss: 1.0134 - accuracy: 0.6444 - val_loss: 0.8903 - val_accuracy: 0.6857
# Epoch 4/15
# 1094/1094 [==============================] - 130s 118ms/step - loss: 0.9000 - accuracy: 0.6873 - val_loss: 0.8589 - val_accuracy: 0.7048
# Epoch 5/15
# 1094/1094 [==============================] - 128s 117ms/step - loss: 0.8125 - accuracy: 0.7190 - val_loss: 0.7927 - val_accuracy: 0.7326
# Epoch 6/15
# 1094/1094 [==============================] - 125s 114ms/step - loss: 0.7488 - accuracy: 0.7425 - val_loss: 0.7096 - val_accuracy: 0.7563
# Epoch 7/15
# 1094/1094 [==============================] - 132s 121ms/step - loss: 0.6857 - accuracy: 0.7632 - val_loss: 0.9530 - val_accuracy: 0.7051
# Epoch 8/15
# 1094/1094 [==============================] - 128s 117ms/step - loss: 0.6375 - accuracy: 0.7787 - val_loss: 0.6868 - val_accuracy: 0.7711
# Epoch 9/15
# 1094/1094 [==============================] - 131s 120ms/step - loss: 0.5904 - accuracy: 0.7981 - val_loss: 0.7309 - val_accuracy: 0.7613
# Epoch 10/15
# 1094/1094 [==============================] - 129s 118ms/step - loss: 0.5538 - accuracy: 0.8109 - val_loss: 0.6365 - val_accuracy: 0.7885
# Epoch 11/15
# 1094/1094 [==============================] - 116s 106ms/step - loss: 0.5164 - accuracy: 0.8223 - val_loss: 0.5931 - val_accuracy: 0.8002
# Epoch 12/15
# 1094/1094 [==============================] - 132s 121ms/step - loss: 0.4933 - accuracy: 0.8320 - val_loss: 0.5717 - val_accuracy: 0.8113
# Epoch 13/15
# 1094/1094 [==============================] - 131s 120ms/step - loss: 0.4573 - accuracy: 0.8419 - val_loss: 0.6515 - val_accuracy: 0.7949
# Epoch 14/15
# 1094/1094 [==============================] - 128s 117ms/step - loss: 0.4351 - accuracy: 0.8499 - val_loss: 0.5810 - val_accuracy: 0.8136
# Epoch 15/15
# 1094/1094 [==============================] - 125s 115ms/step - loss: 0.4162 - accuracy: 0.8562 - val_loss: 0.6137 - val_accuracy: 0.8123
# Accuracy Score:
# ============================
# Train Accuracy Score  :  88.8300%
# Test Accuracy Score   :  80.7000%
# Training Time         :  1909.3389
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.85      0.79      0.82      1000
#   Automobile       0.92      0.90      0.91      1000
#         Bird       0.65      0.78      0.71      1000
#          Cat       0.66      0.65      0.65      1000
#         Deer       0.83      0.76      0.79      1000
#          Dog       0.78      0.68      0.72      1000
#         Frog       0.81      0.87      0.84      1000
#        Horse       0.89      0.82      0.86      1000
#         Ship       0.82      0.94      0.87      1000
#        Truck       0.89      0.88      0.89      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Ship', 'Ship', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A
