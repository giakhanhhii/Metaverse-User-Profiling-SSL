# %% [markdown]
# # Model 8: CNN - HOG

# %%
from functions import cnn
from functions import train_predict_nn
from tensorflow.keras.utils import plot_model

# %%
cnn = cnn((32,32,1))
cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#cnn.summary()

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Train-test split and make prediction (Orginal dataset without scaling)

# %%
train_predict_nn(cnn, clf_name="CNN", data_train='/content/drive/MyDrive/Colab Notebooks/train_hog_cnn.csv', data_test='/content/drive/MyDrive/Colab Notebooks/test_hog_cnn.csv', epochs=15, flatten=0)
# Out:
# Epoch 1/15
# 1094/1094 [==============================] - 22s 8ms/step - loss: 1.8132 - accuracy: 0.3473 - val_loss: 1.4095 - val_accuracy: 0.4980
# Epoch 2/15
# 1094/1094 [==============================] - 8s 7ms/step - loss: 1.4840 - accuracy: 0.4776 - val_loss: 1.3145 - val_accuracy: 0.5439
# Epoch 3/15
# 1094/1094 [==============================] - 8s 7ms/step - loss: 1.3709 - accuracy: 0.5215 - val_loss: 1.2612 - val_accuracy: 0.5639
# Epoch 4/15
# 1094/1094 [==============================] - 8s 7ms/step - loss: 1.3011 - accuracy: 0.5467 - val_loss: 1.1650 - val_accuracy: 0.5988
# Epoch 5/15
# 1094/1094 [==============================] - 8s 7ms/step - loss: 1.2500 - accuracy: 0.5694 - val_loss: 1.1751 - val_accuracy: 0.5906
# Epoch 6/15
# 1094/1094 [==============================] - 8s 7ms/step - loss: 1.1989 - accuracy: 0.5847 - val_loss: 1.0928 - val_accuracy: 0.6246
# Epoch 7/15
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A
