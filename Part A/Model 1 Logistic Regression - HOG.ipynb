# %% [markdown]
# # Model 1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from functions import train_predict_ml, cross_validation

# %% [markdown]
# ### Train-test split and make prediction (HOG Preprocessed Dataset)

# %%
lr = LogisticRegression(random_state=42)

# %%
train_predict_ml(lr, data_train="../Data/train_hog.csv", data_test="../Data/test_hog.csv")
# Out:
# C:\Users\Liujun\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy Score:
# ...
# Train Accuracy Score  :  53.7880%
# Test Accuracy Score   :  52.2600%
# Training Time         :  4.4534
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.58      0.59      0.59      1000
#   Automobile       0.59      0.62      0.61      1000
#         Bird       0.44      0.40      0.42      1000
#          Cat       0.37      0.28      0.32      1000
# ...

# %% [markdown]
# ### Cross-validation

# %%
lr_cv = LogisticRegression(random_state=42)

# %%
cross_validation(lr_cv, data_train="../Data/train_hog.csv")
# Out:
# C:\Users\Liujun\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Liujun\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
