# %% [markdown]
# # Model 2: NB - AUG + PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from sklearn.naive_bayes import GaussianNB
from functions import train_predict_ml, cross_validation

# %%
gnb = GaussianNB()

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_pca.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_aug_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  29.2000 %
# Test Accuracy Score   :  29.4100 %
# Training Time         :  1.1074
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.29      0.10      0.15      1000
#   Automobile       0.32      0.52      0.40      1000
#         Bird       0.23      0.09      0.13      1000
#          Cat       0.24      0.13      0.17      1000
#         Deer       0.26      0.56      0.35      1000
#          Dog       0.35      0.13      0.19      1000
#         Frog       0.40      0.30      0.34      1000
#        Horse       0.26      0.22      0.24      1000
#         Ship       0.34      0.49      0.40      1000
#        Truck       0.27      0.41      0.32      1000
#
#     accuracy                           0.29     10000
#    macro avg       0.29      0.29      0.27     10000
# weighted avg       0.29      0.29      0.27     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.29683333 0.28433333 0.2915     0.28691667 0.23975   ]
# Mean: 0.2798666666666666
# Standard Deviation: 0.02050464716974071
# Training Time: 8.322737216949463
