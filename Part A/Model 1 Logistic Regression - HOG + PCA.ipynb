# %% [markdown]
# # Model 1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from functions import train_predict_ml, cross_validation

# %% [markdown]
# ### Train-test split and make prediction (HOG + PCA Preprocessed Dataset)

# %%
lr = LogisticRegression(random_state=42)

# %%
train_predict_ml(lr, data_train="../Data/train_hog_pca.csv", data_test="../Data/test_hog_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  53.3120%
# Test Accuracy Score   :  52.1300%
# Training Time         :  2.5406
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.59      0.59      0.59      1000
#   Automobile       0.58      0.62      0.60      1000
#         Bird       0.45      0.40      0.42      1000
#          Cat       0.37      0.28      0.32      1000
#         Deer       0.45      0.45      0.45      1000
#          Dog       0.45      0.42      0.44      1000
#         Frog       0.53      0.65      0.58      1000
#        Horse       0.56      0.58      0.57      1000
#         Ship       0.53      0.55      0.54      1000
#        Truck       0.63      0.66      0.64      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.52      0.52      0.52     10000
# weighted avg       0.52      0.52      0.52     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
lr_cv = LogisticRegression(random_state=42)

# %%
cross_validation(lr, data_train="../Data/train_hog_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.5183 0.5236 0.5226 0.5258 0.5229]
# Mean: 0.52264
# Standard Deviation: 0.00244180261282522
# Training Time: 10.92692518234253
