# %% [markdown]
# # Model 5: Random Forest - AUG + HOG + PCA

# %%
from sklearn.ensemble import RandomForestClassifier
from functions import cross_validation
from functions import train_predict_ml

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(rf, data_train="../Data/train_aug_hog_pca.csv", data_test="../Data/test_aug_hog_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  100.0000 %
# Test Accuracy Score   :  51.0100 %
# Training Time         :  166.3472
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.59      0.59      0.59      1000
#   Automobile       0.56      0.68      0.62      1000
#         Bird       0.46      0.35      0.40      1000
#          Cat       0.38      0.29      0.33      1000
#         Deer       0.42      0.38      0.40      1000
#          Dog       0.40      0.43      0.41      1000
#         Frog       0.50      0.67      0.57      1000
#        Horse       0.56      0.54      0.55      1000
#         Ship       0.59      0.59      0.59      1000
#        Truck       0.60      0.59      0.59      1000
#
#     accuracy                           0.51     10000
#    macro avg       0.51      0.51      0.50     10000
# weighted avg       0.51      0.51      0.50     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
rf2=RandomForestClassifier(random_state=42)

# %%
cross_validation(rf2, data_train="../Data/train_aug_hog_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.50516667 0.49925    0.50766667 0.50825    0.4485    ]
# Mean: 0.4937666666666667
# Standard Deviation: 0.022856399541485092
# Training Time: 560.3180210590363
