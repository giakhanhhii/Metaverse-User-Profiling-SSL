# %% [markdown]
# # Model 2: NB - PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from sklearn.naive_bayes import GaussianNB
from functions import train_predict_ml, cross_validation

# %%
gnb = GaussianNB()

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_pca.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  30.1440 %
# Test Accuracy Score   :  29.2500 %
# Training Time         :  0.7415
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.31      0.10      0.16      1000
#   Automobile       0.35      0.47      0.40      1000
#         Bird       0.22      0.10      0.13      1000
#          Cat       0.21      0.12      0.15      1000
#         Deer       0.26      0.58      0.36      1000
#          Dog       0.31      0.14      0.19      1000
#         Frog       0.39      0.26      0.31      1000
#        Horse       0.29      0.23      0.26      1000
#         Ship       0.31      0.52      0.39      1000
#        Truck       0.28      0.40      0.33      1000
#
#     accuracy                           0.29     10000
#    macro avg       0.29      0.29      0.27     10000
# weighted avg       0.29      0.29      0.27     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.2956 0.2798 0.2952 0.278  0.2847]
# Mean: 0.28666
# Standard Deviation: 0.007466619047467194
# Training Time: 5.012533187866211
