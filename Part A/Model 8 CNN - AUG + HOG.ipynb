# %% [markdown]
# # Model 8: CNN - AUG + HOG

# %%
from functions import cnn
from functions import train_predict_nn
from tensorflow.keras.utils import plot_model

# %%
cnn = cnn((32,32,1))
cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#cnn.summary()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %% [markdown]
# ### Train-test split and make prediction (Orginal dataset without scaling)

# %%
train_predict_nn(cnn, clf_name="CNN", data_train='/content/drive/MyDrive/Colab Notebooks/train_aug_hog_cnn.csv', data_test= '/content/drive/MyDrive/Colab Notebooks/test_hog_cnn.csv', epochs=15, flatten=0)
# Out:
# Epoch 1/15
# 1313/1313 [==============================] - 24s 8ms/step - loss: 1.7742 - accuracy: 0.3575 - val_loss: 1.6065 - val_accuracy: 0.4493
# Epoch 2/15
# 1313/1313 [==============================] - 10s 7ms/step - loss: 1.4594 - accuracy: 0.4882 - val_loss: 1.3711 - val_accuracy: 0.5163
# Epoch 3/15
# 1313/1313 [==============================] - 10s 7ms/step - loss: 1.3503 - accuracy: 0.5308 - val_loss: 1.3736 - val_accuracy: 0.5238
# Epoch 4/15
# 1313/1313 [==============================] - 10s 7ms/step - loss: 1.2784 - accuracy: 0.5580 - val_loss: 1.3053 - val_accuracy: 0.5477
# Epoch 5/15
# 1313/1313 [==============================] - 10s 7ms/step - loss: 1.2226 - accuracy: 0.5796 - val_loss: 1.2678 - val_accuracy: 0.5595
# Epoch 6/15
# 1313/1313 [==============================] - 10s 8ms/step - loss: 1.1708 - accuracy: 0.5990 - val_loss: 1.2018 - val_accuracy: 0.5862
# Epoch 7/15
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A
