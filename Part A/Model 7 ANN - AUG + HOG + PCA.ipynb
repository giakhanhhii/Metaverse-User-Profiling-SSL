# %% [markdown]
# # Model 7: ANN

# %%
import tensorflow as tf
from functions import ann, train_predict_nn

# %%
ann = ann((138, ))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train-test split and make prediction (AUG + HOG + PCA Preprocessed Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, data_train='../Data/train_aug_hog_pca.csv',
                data_test='../Data/test_aug_hog_pca.csv')
# Out:
# Epoch 1/20
# 329/329 [==============================] - 2s 4ms/step - loss: 1.3962 - accuracy: 0.5106 - val_loss: 1.3696 - val_accuracy: 0.5240
# Epoch 2/20
# 329/329 [==============================] - 1s 4ms/step - loss: 1.0737 - accuracy: 0.6263 - val_loss: 1.3246 - val_accuracy: 0.5428
# Epoch 3/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.9373 - accuracy: 0.6743 - val_loss: 1.3012 - val_accuracy: 0.5568
# Epoch 4/20
# 329/329 [==============================] - 1s 4ms/step - loss: 0.8172 - accuracy: 0.7160 - val_loss: 1.2951 - val_accuracy: 0.5674
# Epoch 5/20
# 329/329 [==============================] - 1s 3ms/step - loss: 0.7095 - accuracy: 0.7535 - val_loss: 1.3753 - val_accuracy: 0.5636
# Epoch 6/20
# 329/329 [==============================] - 1s 3ms/step - loss: 0.6023 - accuracy: 0.7891 - val_loss: 1.4555 - val_accuracy: 0.5580
# Epoch 7/20
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
