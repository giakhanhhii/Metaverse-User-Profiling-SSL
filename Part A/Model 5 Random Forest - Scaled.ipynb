# %% [markdown]
# # Model 5: Random Forest - Scaled

# %%
from sklearn.ensemble import RandomForestClassifier
from functions import cross_validation
from functions import train_predict_ml

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction (original dataset with scaling)

# %%
train_predict_ml(rf)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# Accuracy Score:
# ============================
# Train Accuracy Score  :  100.0000 %
# Test Accuracy Score   :  46.5400 %
# Training Time         :  249.3558
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.54      0.56      0.55      1000
#   Automobile       0.52      0.54      0.53      1000
#         Bird       0.38      0.33      0.35      1000
#          Cat       0.33      0.28      0.30      1000
#         Deer       0.39      0.38      0.39      1000
#          Dog       0.43      0.40      0.41      1000
#         Frog       0.47      0.57      0.52      1000
#        Horse       0.51      0.45      0.48      1000
#         Ship       0.58      0.61      0.59      1000
#        Truck       0.47      0.52      0.50      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.46      0.47      0.46     10000
# weighted avg       0.46      0.47      0.46     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Ship', 'Ship', 'Deer', 'Frog', 'Dog', 'Frog', 'Dog', 'Ship']

# %% [markdown]
# ### Cross-validation

# %%
rf2=RandomForestClassifier(random_state=42)
cross_validation(rf2)
# Out:
# Model Accuracies:
# Individual Accuracy: [0.4609 0.4551 0.4573 0.4532 0.4574]
# Mean: 0.45678
# Standard Deviation: 0.0025794573072644485
# Training Time: 972.2258968353271
