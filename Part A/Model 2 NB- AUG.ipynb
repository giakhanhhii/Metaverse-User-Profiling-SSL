# %% [markdown]
# # Model 2: NB - AUG

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from sklearn.naive_bayes import GaussianNB
from functions import train_predict_ml, cross_validation

# %%
gnb = GaussianNB()

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug.csv")
# Out:
# ...
# 170498071/170498071 [==============================] - 4s 0us/step
# Accuracy Score:
# ...
# Train Accuracy Score  :  28.2150%
# Test Accuracy Score   :  29.5900%
# Training Time         :  7.0122
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.27      0.49      0.35      1000
#   Automobile       0.40      0.17      0.24      1000
#         Bird       0.18      0.08      0.11      1000
#          Cat       0.24      0.08      0.12      1000
#         Deer       0.24      0.41      0.30      1000
#          Dog       0.31      0.26      0.28      1000
#         Frog       0.25      0.47      0.33      1000
#        Horse       0.42      0.13      0.20      1000
#         Ship       0.39      0.47      0.42      1000
#        Truck       0.38      0.41      0.39      1000
#
#     accuracy                           0.30     10000
#    macro avg       0.31      0.30      0.27     10000
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.2875     0.28325    0.28       0.28375    0.27308333]
# Mean: 0.2815166666666667
# Standard Deviation: 0.004841774238621383
# Training Time: 47.98701882362366
