# %% [markdown]
# # Model 5: Random Forest - Original dataset

# %%
from sklearn.ensemble import RandomForestClassifier
from functions import cross_validation
from functions import train_predict_ml

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction (Orginal dataset without scaling)

# %%
train_predict_ml(rf, scale=0)
# Out:
# Accuracy Score:
# ============================
# Train Accuracy Score  :  100.0000 %
# Test Accuracy Score   :  46.5400 %
# Training Time         :  163.5544
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.54      0.56      0.55      1000
#   Automobile       0.52      0.54      0.53      1000
#         Bird       0.37      0.33      0.35      1000
#          Cat       0.33      0.28      0.31      1000
#         Deer       0.39      0.38      0.38      1000
#          Dog       0.43      0.40      0.41      1000
#         Frog       0.48      0.57      0.52      1000
#        Horse       0.51      0.45      0.48      1000
#         Ship       0.58      0.61      0.59      1000
#        Truck       0.47      0.53      0.50      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.46      0.47      0.46     10000
# weighted avg       0.46      0.47      0.46     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Ship', 'Ship', 'Deer', 'Frog', 'Dog', 'Frog', 'Dog', 'Ship']

# %% [markdown]
# ### Cross-validation

# %%
rf2 = RandomForestClassifier(random_state=42)
cross_validation(rf2,scale=0)
# Out:
# Model Accuracies:
# Individual Accuracy: [0.4609 0.455  0.4574 0.4534 0.4564]
# Mean: 0.45662
# Standard Deviation: 0.0025285569006846397
# Training Time: 642.0362706184387
