# %% [markdown]
# # Model 7: ANN

# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from functions import ann, train_predict_nn

# %%
ann = ann((32, 32, 3))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 512)               1573376
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 10)                330
#
# ...
# Total params: 1,723,562
# Trainable params: 1,723,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(ann, to_file='ann.png', show_shapes=True)

# %% [markdown]
# ### Train-test split and make prediction (Original Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, scale=0, flatten=0)
# Out:
# Epoch 1/20
# 274/274 [==============================] - 4s 12ms/step - loss: 32.0668 - accuracy: 0.1361 - val_loss: 3.7227 - val_accuracy: 0.1185
# Epoch 2/20
# 274/274 [==============================] - 3s 11ms/step - loss: 3.2578 - accuracy: 0.1355 - val_loss: 2.3004 - val_accuracy: 0.0949
# Epoch 3/20
# 274/274 [==============================] - 3s 10ms/step - loss: 2.2773 - accuracy: 0.1335 - val_loss: 2.2418 - val_accuracy: 0.1627
# Epoch 4/20
# 274/274 [==============================] - 3s 10ms/step - loss: 2.2104 - accuracy: 0.1595 - val_loss: 2.1741 - val_accuracy: 0.1541
# Epoch 5/20
# 274/274 [==============================] - 3s 10ms/step - loss: 2.1534 - accuracy: 0.1675 - val_loss: 2.1448 - val_accuracy: 0.1706
# Epoch 6/20
# 274/274 [==============================] - 3s 10ms/step - loss: 2.1174 - accuracy: 0.1780 - val_loss: 2.1075 - val_accuracy: 0.1800
# Epoch 7/20
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
