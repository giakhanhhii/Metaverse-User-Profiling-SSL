# %% [markdown]
# # Model 7: ANN

# %%
import tensorflow as tf
from functions import ann, train_predict_nn

# %%
ann = ann((324, ))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train-test split and make prediction (HOG Preprocessed Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, data_train='../Data/train_hog.csv', 
                data_test='../Data/test_hog.csv')
# Out:
# Epoch 1/20
# 274/274 [==============================] - 2s 5ms/step - loss: 1.6232 - accuracy: 0.4222 - val_loss: 1.4071 - val_accuracy: 0.5105
# Epoch 2/20
# 274/274 [==============================] - 1s 4ms/step - loss: 1.3141 - accuracy: 0.5390 - val_loss: 1.2662 - val_accuracy: 0.5562
# Epoch 3/20
# 274/274 [==============================] - 1s 4ms/step - loss: 1.2110 - accuracy: 0.5752 - val_loss: 1.2218 - val_accuracy: 0.5711
# Epoch 4/20
# 274/274 [==============================] - 1s 4ms/step - loss: 1.1338 - accuracy: 0.6026 - val_loss: 1.1534 - val_accuracy: 0.5995
# Epoch 5/20
# 274/274 [==============================] - 1s 4ms/step - loss: 1.0743 - accuracy: 0.6243 - val_loss: 1.1216 - val_accuracy: 0.6141
# Epoch 6/20
# 274/274 [==============================] - 1s 4ms/step - loss: 1.0202 - accuracy: 0.6433 - val_loss: 1.1383 - val_accuracy: 0.6074
# Epoch 7/20
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
