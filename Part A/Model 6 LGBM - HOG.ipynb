# %% [markdown]
# # Model 3: LGBM - HOG

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from lightgbm import LGBMClassifier
from functions import train_predict_ml, cross_validation

# %%
lgbm = LGBMClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_hog.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_hog.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  87.3920 %
# Test Accuracy Score   :  59.8500 %
# Training Time         :  85.5613
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.65      0.66      0.65      1000
#   Automobile       0.71      0.73      0.72      1000
#         Bird       0.51      0.46      0.48      1000
#          Cat       0.44      0.40      0.42      1000
#         Deer       0.52      0.56      0.54      1000
#          Dog       0.48      0.48      0.48      1000
#         Frog       0.63      0.69      0.66      1000
#        Horse       0.66      0.64      0.65      1000
#         Ship       0.66      0.66      0.66      1000
#        Truck       0.70      0.71      0.71      1000
#
#     accuracy                           0.60     10000
#    macro avg       0.60      0.60      0.60     10000
# weighted avg       0.60      0.60      0.60     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.5899 0.598  0.5986 0.5934 0.5973]
# Mean: 0.5954400000000001
# Standard Deviation: 0.0033121594164532684
# Training Time: 367.5402114391327
