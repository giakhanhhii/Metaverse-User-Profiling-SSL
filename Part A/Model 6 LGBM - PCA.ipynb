# %% [markdown]
# # Model 3: LGBM - PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from lightgbm import LGBMClassifier
from functions import train_predict_ml, cross_validation

# %%
lgbm = LGBMClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_pca.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  86.3300 %
# Test Accuracy Score   :  50.6400 %
# Training Time         :  318.1358
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.57      0.57      0.57      1000
#   Automobile       0.58      0.62      0.60      1000
#         Bird       0.41      0.36      0.38      1000
#          Cat       0.35      0.34      0.34      1000
#         Deer       0.46      0.41      0.43      1000
#          Dog       0.43      0.39      0.41      1000
#         Frog       0.55      0.64      0.59      1000
#        Horse       0.55      0.54      0.55      1000
#         Ship       0.58      0.65      0.61      1000
#        Truck       0.53      0.57      0.55      1000
#
#     accuracy                           0.51     10000
#    macro avg       0.50      0.51      0.50     10000
# weighted avg       0.50      0.51      0.50     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.5038 0.5009 0.5039 0.5026 0.5005]
# Mean: 0.50234
# Standard Deviation: 0.0014207040508142654
# Training Time: 1416.9448261260986
