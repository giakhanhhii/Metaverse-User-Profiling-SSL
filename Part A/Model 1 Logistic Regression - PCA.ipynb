# %% [markdown]
# # Model 1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from functions import train_predict_ml, cross_validation

# %% [markdown]
# ### Train-test split and make prediction (PCA Preprocessed Dataset)

# %%
lr = LogisticRegression(random_state=42)

# %%
train_predict_ml(lr, data_train="../Data/train_pca.csv", data_test="../Data/test_pca.csv")
# Out:
# C:\Users\Liujun\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy Score:
# ...
# Train Accuracy Score  :  45.1720%
# Test Accuracy Score   :  40.4000%
# Training Time         :  7.5362
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.46      0.48      0.47      1000
#   Automobile       0.46      0.47      0.47      1000
#         Bird       0.32      0.29      0.30      1000
#          Cat       0.28      0.26      0.27      1000
# ...

# %% [markdown]
# ### Cross-validation

# %%
lr_cv = LogisticRegression(random_state=42)

# %%
cross_validation(lr_cv, data_train="../Data/train_pca.csv")
# Out:
# C:\Users\Liujun\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Liujun\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
