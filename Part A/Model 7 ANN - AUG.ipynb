# %% [markdown]
# # Model 7: ANN

# %%
import tensorflow as tf
from functions import ann, train_predict_nn

# %%
ann = ann((32, 32, 3))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train-test split and make prediction (AUG Preprocessed Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, data_train='../Data/train_aug.csv', flatten=0)
# Out:
# Epoch 1/20
# 329/329 [==============================] - 11s 28ms/step - loss: 1.9911 - accuracy: 0.2771 - val_loss: 1.8983 - val_accuracy: 0.3192
# Epoch 2/20
# 329/329 [==============================] - 7s 22ms/step - loss: 1.7536 - accuracy: 0.3707 - val_loss: 1.7826 - val_accuracy: 0.3613
# Epoch 3/20
# 329/329 [==============================] - 7s 22ms/step - loss: 1.6693 - accuracy: 0.4023 - val_loss: 1.7738 - val_accuracy: 0.3605
# Epoch 4/20
# 329/329 [==============================] - 7s 22ms/step - loss: 1.6063 - accuracy: 0.4254 - val_loss: 1.6362 - val_accuracy: 0.4132
# Epoch 5/20
# 329/329 [==============================] - 7s 23ms/step - loss: 1.5590 - accuracy: 0.4416 - val_loss: 1.6021 - val_accuracy: 0.4278
# Epoch 6/20
# 329/329 [==============================] - 7s 22ms/step - loss: 1.5164 - accuracy: 0.4574 - val_loss: 1.6065 - val_accuracy: 0.4229
# Epoch 7/20
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
