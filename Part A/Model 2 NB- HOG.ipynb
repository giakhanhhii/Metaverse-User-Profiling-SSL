# %% [markdown]
# # Model 2: NB - HOG

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from sklearn.naive_bayes import GaussianNB
from functions import train_predict_ml, cross_validation

# %%
gnb = GaussianNB()

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_hog.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_hog.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  47.0500 %
# Test Accuracy Score   :  47.0200 %
# Training Time         :  0.3688
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.55      0.45      0.49      1000
#   Automobile       0.47      0.52      0.49      1000
#         Bird       0.40      0.33      0.36      1000
#          Cat       0.39      0.26      0.31      1000
#         Deer       0.44      0.37      0.40      1000
#          Dog       0.38      0.52      0.44      1000
#         Frog       0.48      0.63      0.55      1000
#        Horse       0.58      0.46      0.51      1000
#         Ship       0.47      0.58      0.52      1000
#        Truck       0.59      0.58      0.58      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.47      0.47      0.47     10000
# weighted avg       0.47      0.47      0.47     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.4674 0.4707 0.4728 0.4563 0.4685]
# Mean: 0.46713999999999994
# Standard Deviation: 0.005729432781698384
# Training Time: 2.2519993782043457
