# %% [markdown]
# # Model 3: KNN - AUG

# %%
from sklearn.neighbors import KNeighborsClassifier
from functions import cross_validation
from functions import train_predict_ml
# import warnings
# warnings.filterwarnings("ignore")

# %%
knn = KNeighborsClassifier()

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(knn, data_train="../Data/train_aug.csv")
# Out:
# Accuracy Score:
# ============================
# Train Accuracy Score  :  52.9683%
# Test Accuracy Score   :  34.3800%
# Training Time         :  0.2828
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.37      0.54      0.44      1000
#   Automobile       0.65      0.22      0.33      1000
#         Bird       0.23      0.45      0.30      1000
#          Cat       0.29      0.22      0.25      1000
#         Deer       0.25      0.50      0.34      1000
#          Dog       0.40      0.23      0.29      1000
#         Frog       0.35      0.27      0.31      1000
#        Horse       0.66      0.22      0.33      1000
#         Ship       0.41      0.64      0.50      1000
#        Truck       0.70      0.14      0.24      1000
#
#     accuracy                           0.34     10000
#    macro avg       0.43      0.34      0.33     10000
# weighted avg       0.43      0.34      0.33     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Bird', 'Ship', 'Ship', 'Airplane', 'Deer', 'Frog', 'Frog', 'Bird', 'Deer', 'Ship']

# %% [markdown]
# ### Cross-validation

# %%
knn2 = KNeighborsClassifier()

# %%
cross_validation(knn2, data_train="../Data/train_aug.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.35       0.34733333 0.35058333 0.34341667 0.34983333]
# Mean: 0.3482333333333333
# Standard Deviation: 0.0026538232378547407
# Training Time: 202.904381275177
