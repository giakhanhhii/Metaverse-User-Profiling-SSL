# %% [markdown]
# # Model 7: ANN

# %%
import tensorflow as tf
from functions import ann, train_predict_nn

# %%
ann = ann((138, ))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train-test split and make prediction (HOG + PCA Preprocessed Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, data_train='../Data/train_hog_pca.csv', 
                data_test='../Data/test_hog_pca.csv')
# Out:
# Epoch 1/20
# 274/274 [==============================] - 2s 4ms/step - loss: 1.4144 - accuracy: 0.5040 - val_loss: 1.2597 - val_accuracy: 0.5654
# Epoch 2/20
# 274/274 [==============================] - 1s 3ms/step - loss: 1.0984 - accuracy: 0.6157 - val_loss: 1.1639 - val_accuracy: 0.6027
# Epoch 3/20
# 274/274 [==============================] - 1s 3ms/step - loss: 0.9386 - accuracy: 0.6712 - val_loss: 1.1301 - val_accuracy: 0.6157
# Epoch 4/20
# 274/274 [==============================] - 1s 3ms/step - loss: 0.8012 - accuracy: 0.7211 - val_loss: 1.1539 - val_accuracy: 0.6105
# Epoch 5/20
# 274/274 [==============================] - 1s 3ms/step - loss: 0.6807 - accuracy: 0.7625 - val_loss: 1.1919 - val_accuracy: 0.6124
# Epoch 6/20
# 274/274 [==============================] - 1s 3ms/step - loss: 0.5593 - accuracy: 0.8064 - val_loss: 1.2864 - val_accuracy: 0.5977
# Epoch 7/20
# ...

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
