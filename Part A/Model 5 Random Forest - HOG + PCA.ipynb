# %% [markdown]
# # Model 5: Random Forest- PCA

# %%
from sklearn.ensemble import RandomForestClassifier
from functions import cross_validation
from functions import train_predict_ml

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(rf, data_train="../Data/train_pca.csv",data_test="../Data/test_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  100.0000 %
# Test Accuracy Score   :  38.0700 %
# Training Time         :  331.6333
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.44      0.47      0.46      1000
#   Automobile       0.40      0.47      0.43      1000
#         Bird       0.27      0.24      0.26      1000
#          Cat       0.26      0.24      0.25      1000
#         Deer       0.37      0.36      0.36      1000
#          Dog       0.32      0.31      0.31      1000
#         Frog       0.45      0.45      0.45      1000
#        Horse       0.41      0.32      0.36      1000
#         Ship       0.49      0.54      0.52      1000
#        Truck       0.37      0.39      0.38      1000
#
#     accuracy                           0.38     10000
#    macro avg       0.38      0.38      0.38     10000
# weighted avg       0.38      0.38      0.38     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
rf2=RandomForestClassifier(random_state=42)

# %%
cross_validation(rf2, data_train="../Data/train_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.3825 0.3787 0.3826 0.3759 0.3873]
# Mean: 0.38139999999999996
# Standard Deviation: 0.003872983346207409
# Training Time: 1279.2948236465454
