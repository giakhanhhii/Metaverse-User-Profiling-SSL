# %% [markdown]
# # Model 3: LGBM - AUG + HOG + PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')
# Out:
# /content/drive/MyDrive/Colab Notebooks
# '/content/drive/MyDrive/Colab Notebooks'

# %%
from lightgbm import LGBMClassifier
from functions import train_predict_ml, cross_validation

# %%
lgbm = LGBMClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_hog_pca.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_aug_hog_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  80.1233 %
# Test Accuracy Score   :  57.8100 %
# Training Time         :  42.0856
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.65      0.64      0.65      1000
#   Automobile       0.67      0.72      0.70      1000
#         Bird       0.52      0.44      0.48      1000
#          Cat       0.41      0.34      0.37      1000
#         Deer       0.50      0.52      0.51      1000
#          Dog       0.45      0.45      0.45      1000
#         Frog       0.61      0.71      0.66      1000
#        Horse       0.62      0.61      0.61      1000
#         Ship       0.64      0.65      0.64      1000
#        Truck       0.66      0.70      0.68      1000
#
#     accuracy                           0.58     10000
#    macro avg       0.57      0.58      0.57     10000
# weighted avg       0.57      0.58      0.57     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_hog_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.57391667 0.56891667 0.576      0.57191667 0.50383333]
# Mean: 0.5589166666666667
# Standard Deviation: 0.027640600170361285
# Training Time: 185.42708492279053
