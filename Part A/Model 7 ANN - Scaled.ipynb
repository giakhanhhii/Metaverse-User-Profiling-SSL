# %% [markdown]
# # Model 7: ANN - Scaled

# %%
import tensorflow as tf
from functions import ann, train_predict_nn

# %%
ann = ann((32, 32, 3))
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train-test split and make prediction (Scaled Dataset)

# %%
train_predict_nn(ann, 'Artificial Neural Network (ANN)', 20, batch_size=128, flatten=0)
# Out:
# Epoch 1/20
# 274/274 [==============================] - 4s 12ms/step - loss: 2.0209 - accuracy: 0.2578 - val_loss: 1.8955 - val_accuracy: 0.3209
# Epoch 2/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.8075 - accuracy: 0.3513 - val_loss: 1.7595 - val_accuracy: 0.3667
# Epoch 3/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.7025 - accuracy: 0.3868 - val_loss: 1.6773 - val_accuracy: 0.3989
# Epoch 4/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.6406 - accuracy: 0.4113 - val_loss: 1.6333 - val_accuracy: 0.4185
# Epoch 5/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.5811 - accuracy: 0.4319 - val_loss: 1.5772 - val_accuracy: 0.4359
# Epoch 6/20
# 274/274 [==============================] - 3s 10ms/step - loss: 1.5270 - accuracy: 0.4539 - val_loss: 1.5537 - val_accuracy: 0.4432
# Epoch 7/20
# 274/274 [==============================] - 3s 10ms/step - loss: 1.4982 - accuracy: 0.4651 - val_loss: 1.5847 - val_accuracy: 0.4334
# Epoch 8/20
# 274/274 [==============================] - 3s 10ms/step - loss: 1.4735 - accuracy: 0.4722 - val_loss: 1.5992 - val_accuracy: 0.4359
# Epoch 9/20
# 274/274 [==============================] - 3s 10ms/step - loss: 1.4425 - accuracy: 0.4851 - val_loss: 1.5688 - val_accuracy: 0.4475
# Epoch 10/20
# 274/274 [==============================] - 3s 10ms/step - loss: 1.4171 - accuracy: 0.4938 - val_loss: 1.5217 - val_accuracy: 0.4565
# Epoch 11/20
# 274/274 [==============================] - 3s 11ms/step - loss: 1.3919 - accuracy: 0.5038 - val_loss: 1.5108 - val_accuracy: 0.4678
# Epoch 12/20
# 274/274 [==============================] - 3s 11ms/step - loss: 1.3690 - accuracy: 0.5093 - val_loss: 1.5068 - val_accuracy: 0.4685
# Epoch 13/20
# 274/274 [==============================] - 3s 11ms/step - loss: 1.3440 - accuracy: 0.5185 - val_loss: 1.4710 - val_accuracy: 0.4825
# Epoch 14/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.3258 - accuracy: 0.5235 - val_loss: 1.4737 - val_accuracy: 0.4768
# Epoch 15/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.2977 - accuracy: 0.5358 - val_loss: 1.4548 - val_accuracy: 0.4854
# Epoch 16/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.2835 - accuracy: 0.5392 - val_loss: 1.4569 - val_accuracy: 0.4874
# Epoch 17/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.2550 - accuracy: 0.5509 - val_loss: 1.4565 - val_accuracy: 0.4904
# Epoch 18/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.2413 - accuracy: 0.5589 - val_loss: 1.4600 - val_accuracy: 0.4899
# Epoch 19/20
# 274/274 [==============================] - 3s 11ms/step - loss: 1.2222 - accuracy: 0.5611 - val_loss: 1.4345 - val_accuracy: 0.4939
# Epoch 20/20
# 274/274 [==============================] - 3s 12ms/step - loss: 1.1991 - accuracy: 0.5698 - val_loss: 1.4679 - val_accuracy: 0.4885
# Accuracy Score:
# ============================
# Train Accuracy Score  :  55.1580%
# Test Accuracy Score   :  49.8900%
# Training Time         :  63.3319
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.56      0.62      0.59      1000
#   Automobile       0.52      0.71      0.60      1000
#         Bird       0.38      0.40      0.39      1000
#          Cat       0.37      0.35      0.36      1000
#         Deer       0.58      0.22      0.32      1000
#          Dog       0.40      0.42      0.41      1000
#         Frog       0.50      0.61      0.55      1000
#        Horse       0.61      0.52      0.56      1000
#         Ship       0.65      0.58      0.61      1000
#        Truck       0.51      0.56      0.53      1000
#
#     accuracy                           0.50     10000
#    macro avg       0.51      0.50      0.49     10000
# weighted avg       0.51      0.50      0.49     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Automobile', 'Automobile', 'Airplane', 'Deer', 'Frog', 'Automobile', 'Frog', 'Bird', 'Truck']

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# N/A because it requires too much resource and time to perform cross validation on deep learning models.
