# %% [markdown]
# # Model 3: LGBM - AUG + PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from lightgbm import LGBMClassifier
from functions import train_predict_ml, cross_validation

# %%
lgbm = LGBMClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_pca.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_aug_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  81.4967 %
# Test Accuracy Score   :  51.6900 %
# Training Time         :  334.8766
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.57      0.59      0.58      1000
#   Automobile       0.58      0.64      0.61      1000
#         Bird       0.43      0.34      0.38      1000
#          Cat       0.35      0.33      0.34      1000
#         Deer       0.49      0.42      0.45      1000
#          Dog       0.44      0.40      0.42      1000
#         Frog       0.55      0.67      0.61      1000
#        Horse       0.56      0.54      0.55      1000
#         Ship       0.61      0.65      0.63      1000
#        Truck       0.53      0.60      0.56      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.51      0.52      0.51     10000
# weighted avg       0.51      0.52      0.51     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.51783333 0.50558333 0.51458333 0.5035     0.48191667]
# Mean: 0.5046833333333334
# Standard Deviation: 0.012581445774543475
# Training Time: 1446.391438484192
