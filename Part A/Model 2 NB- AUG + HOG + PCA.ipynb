# %% [markdown]
# # Model 2: NB - AUG + HOG + PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from sklearn.naive_bayes import GaussianNB
from functions import train_predict_ml, cross_validation

# %%
gnb = GaussianNB()

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_hog_pca.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_aug_hog_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  48.3583 %
# Test Accuracy Score   :  49.3700 %
# Training Time         :  0.1849
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.54      0.42      0.48      1000
#   Automobile       0.64      0.56      0.59      1000
#         Bird       0.43      0.33      0.37      1000
#          Cat       0.33      0.45      0.38      1000
#         Deer       0.41      0.53      0.46      1000
#          Dog       0.46      0.37      0.41      1000
#         Frog       0.55      0.63      0.59      1000
#        Horse       0.60      0.48      0.53      1000
#         Ship       0.44      0.59      0.51      1000
#        Truck       0.67      0.57      0.62      1000
#
#     accuracy                           0.49     10000
#    macro avg       0.51      0.49      0.49     10000
# weighted avg       0.51      0.49      0.49     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(gnb, data_train="/content/drive/MyDrive/Colab Notebooks/train_aug_hog_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.49125    0.48641667 0.48916667 0.48316667 0.42516667]
# Mean: 0.47503333333333336
# Standard Deviation: 0.02508045941454112
# Training Time: 0.9698185920715332
