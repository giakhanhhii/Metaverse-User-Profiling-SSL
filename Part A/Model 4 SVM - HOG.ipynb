# %% [markdown]
# # Model 4: SVM - HOG

# %%
from sklearn import svm
from functions import cross_validation
from functions import train_predict_ml

# %%
svc=svm.SVC(random_state=42,probability=True)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(svc, data_train="../Data/train_hog.csv", data_test="../Data/test_hog.csv")
# Out:
# Accuracy Score:
# ============================
# Train Accuracy Score  :  80.5540 %
# Test Accuracy Score   :  64.7200 %
# Training Time         :  16930.2905
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.68      0.74      0.71      1000
#   Automobile       0.77      0.78      0.77      1000
#         Bird       0.56      0.52      0.54      1000
#          Cat       0.47      0.44      0.46      1000
#         Deer       0.57      0.62      0.59      1000
#          Dog       0.52      0.52      0.52      1000
#         Frog       0.69      0.75      0.72      1000
#        Horse       0.72      0.67      0.70      1000
#         Ship       0.72      0.70      0.71      1000
#        Truck       0.75      0.74      0.74      1000
#
#     accuracy                           0.65     10000
#    macro avg       0.65      0.65      0.65     10000
# weighted avg       0.65      0.65      0.65     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Automobile', 'Airplane', 'Cat', 'Frog', 'Frog', 'Frog', 'Cat', 'Frog']

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(svc, data_train="../Data/train_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.6428 0.6394 0.6414 0.6402 0.6504]
# Mean: 0.64284
# Standard Deviation: 0.0039504936400404445
# Training Time: 51441.04205584526
