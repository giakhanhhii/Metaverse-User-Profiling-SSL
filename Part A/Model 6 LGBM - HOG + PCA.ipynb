# %% [markdown]
# # Model 3: LGBM - HOG + PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks')

# %%
from lightgbm import LGBMClassifier
from functions import train_predict_ml, cross_validation

# %%
lgbm = LGBMClassifier(random_state=42)

# %% [markdown]
# ### Train-test split and make prediction

# %%
train_predict_ml(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_hog_pca.csv", data_test="/content/drive/MyDrive/Colab Notebooks/test_hog_pca.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  84.3180 %
# Test Accuracy Score   :  57.7300 %
# Training Time         :  65.6325
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.64      0.65      0.64      1000
#   Automobile       0.65      0.70      0.68      1000
#         Bird       0.51      0.44      0.47      1000
#          Cat       0.44      0.36      0.40      1000
#         Deer       0.51      0.54      0.52      1000
#          Dog       0.46      0.46      0.46      1000
#         Frog       0.62      0.69      0.65      1000
#        Horse       0.61      0.60      0.60      1000
#         Ship       0.63      0.64      0.63      1000
#        Truck       0.66      0.69      0.68      1000
#
#     accuracy                           0.58     10000
#    macro avg       0.57      0.58      0.57     10000
# weighted avg       0.57      0.58      0.57     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### Cross-validation

# %%
cross_validation(lgbm, data_train="/content/drive/MyDrive/Colab Notebooks/train_hog_pca.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.5694 0.5691 0.5723 0.5728 0.5736]
# Mean: 0.57144
# Standard Deviation: 0.0018380424369420676
# Training Time: 288.5762655735016
