# %% [markdown]
# # Bayesian Optimization - CNN

# %%
from functions import cnn
from functions import train_predict_nn
from tensorflow.keras.utils import plot_model
from keras.optimizers import Adam

# %%
cnn = cnn((32,32,3))

# %%
cnn.compile(optimizer=Adam(learning_rate=1.8302752754300172e-05),loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
train_predict_nn(cnn, clf_name="CNN", epochs=400,flatten=0)
# Out:
# Epoch 1/400
# 1094/1094 [==============================] - 9s 8ms/step - loss: 1.3781 - accuracy: 0.4998 - val_loss: 1.4585 - val_accuracy: 0.5042
# Epoch 2/400
# 1094/1094 [==============================] - 10s 9ms/step - loss: 1.3465 - accuracy: 0.5142 - val_loss: 1.3899 - val_accuracy: 0.5243
# Epoch 3/400
# 1094/1094 [==============================] - 9s 8ms/step - loss: 1.3137 - accuracy: 0.5269 - val_loss: 1.3833 - val_accuracy: 0.5325
# Epoch 4/400
# 1094/1094 [==============================] - 9s 8ms/step - loss: 1.2844 - accuracy: 0.5384 - val_loss: 1.3758 - val_accuracy: 0.5363
# Epoch 5/400
# 1094/1094 [==============================] - 9s 8ms/step - loss: 1.2584 - accuracy: 0.5493 - val_loss: 1.3263 - val_accuracy: 0.5519
# Epoch 6/400
# 1094/1094 [==============================] - 9s 8ms/step - loss: 1.2355 - accuracy: 0.5591 - val_loss: 1.2989 - val_accuracy: 0.5587
# Epoch 7/400
# ...

# %%
cnn.save('cnn.h5')
