# %% [markdown]
# # Bayesian Optimization Result for KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from functions import cross_validation
from functions import train_predict_ml

# %% [markdown]
# ### Train-test split and make prediction

# %% [markdown]
# Original train test split score =  54.3800 %
#
# Original CV Acc score =  53.468% %

# %%
params2={'algorithm': 'ball_tree', 'n_neighbors': 14, 'weights': 'distance'}

# %%
knn2 = KNeighborsClassifier(**params2)
knn2
# Out:
# KNeighborsClassifier(algorithm='ball_tree', n_neighbors=14, weights='distance')

# %%
train_predict_ml(knn2, data_train="../Data/train_hog.csv", data_test="../Data/test_hog.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  100.0000 %
# Test Accuracy Score   :  55.9600 %
# Training Time         :  1.8819
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.80      0.50      0.62      1000
#   Automobile       0.73      0.74      0.74      1000
#         Bird       0.60      0.37      0.46      1000
#          Cat       0.53      0.13      0.21      1000
#         Deer       0.36      0.67      0.47      1000
#          Dog       0.54      0.33      0.41      1000
#         Frog       0.41      0.85      0.55      1000
#        Horse       0.74      0.58      0.65      1000
#         Ship       0.63      0.69      0.66      1000
#        Truck       0.68      0.73      0.70      1000
#
#     accuracy                           0.56     10000
#    macro avg       0.60      0.56      0.55     10000
# weighted avg       0.60      0.56      0.55     10000
#
#
# Confusion Matrix:
# ...

# %%
cross_validation(knn2, data_train="../Data/train_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.5503 0.5548 0.556  0.5515 0.5543]
# Mean: 0.55338
# Standard Deviation: 0.0021329791372631914
# Training Time: 1335.6656775474548
