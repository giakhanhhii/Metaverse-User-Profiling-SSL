# %% [markdown]
# # Bayesian Optimization Result for LGBM

# %%
from functions import train_predict_ml, cross_validation, load_data
from lightgbm import LGBMClassifier
import lightgbm as lgb

# %% [markdown]
# # Test on Tuned Result

# %%
params={'learning_rate': 0.09767600511205632, 'max_depth': 13, 'min_child_samples': 5, 'num_leaves': 88, 'reg_alpha': 0.13123725784077744}

# %%
lgbm = LGBMClassifier(**params,random_state=42)
lgbm
# Out:
# LGBMClassifier(learning_rate=0.09767600511205632, max_depth=13,
#                min_child_samples=5, num_leaves=88, random_state=42,
#                reg_alpha=0.13123725784077744)

# %%
train_predict_ml(lgbm, data_train="../Data/train_hog.csv", data_test="../Data/test_hog.csv")
# Out:
# Accuracy Score:
# ============================
# Train Accuracy Score  :  99.9500 %
# Test Accuracy Score   :  61.0300 %
# Training Time         :  135.2210
#
# Classification Report:
# ============================
#               precision    recall  f1-score   support
#
#     Airplane       0.67      0.68      0.68      1000
#   Automobile       0.72      0.74      0.73      1000
#         Bird       0.52      0.47      0.49      1000
#          Cat       0.44      0.42      0.43      1000
#         Deer       0.53      0.58      0.55      1000
#          Dog       0.49      0.49      0.49      1000
#         Frog       0.64      0.69      0.66      1000
#        Horse       0.69      0.66      0.67      1000
#         Ship       0.67      0.68      0.68      1000
#        Truck       0.70      0.70      0.70      1000
#
#     accuracy                           0.61     10000
#    macro avg       0.61      0.61      0.61     10000
# weighted avg       0.61      0.61      0.61     10000
#
#
# Confusion Matrix:
# ============================
# Predicted and Actual Test Set Results:
# ========================================
# Predicted Results: ['Cat', 'Ship', 'Ship', 'Airplane', 'Frog', 'Frog', 'Automobile', 'Frog', 'Cat', 'Automobile']
# Actual Results: ['Cat', 'Ship', 'Automobile', 'Airplane', 'Frog', 'Frog', 'Dog', 'Frog', 'Cat', 'Automobile']

# %%
cross_validation(lgbm, data_train="../Data/train_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.6033 0.6035 0.6053 0.6027 0.6027]
# Mean: 0.6034999999999999
# Standard Deviation: 0.0009549869109050443
# Training Time: 375.0706889629364

# %% [markdown]
# ### Add early stopping to avoid overfitting issues

# %% [markdown]
# Terrible result --> ignore

# %%
from functions import load_data
(x_train, x_test, y_train, y_test) = load_data(data_train="../Data/train_hog.csv", data_test="../Data/test_hog.csv")

# %%
train_data = lgb.Dataset(x_train, label=y_train)
val_data = lgb.Dataset(x_test, label=y_test)

# %%
params = {
    'objective': 'binary',
    'metric': 'auc',
    'boosting_type': 'gbdt',
    'lambda_l1': 0.1,
    'lambda_l2': 0.1,
    'min_gain_to_split': 0.1,
    'num_leaves': 31,
    'learning_rate': 0.05,
    'verbose': -1
}

gbm = lgb.train(params,
                train_data,
                valid_sets=[val_data],
                early_stopping_rounds=10)
# Out:
# C:\Users\jiyeo\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's auc: 0.804309
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's auc: 0.821565
# [3]	valid_0's auc: 0.847317
# [4]	valid_0's auc: 0.851289
# [5]	valid_0's auc: 0.859633
# [6]	valid_0's auc: 0.862669
# [7]	valid_0's auc: 0.866918
# [8]	valid_0's auc: 0.870739
# [9]	valid_0's auc: 0.872626
# [10]	valid_0's auc: 0.876906
# [11]	valid_0's auc: 0.880457
# [12]	valid_0's auc: 0.882049
# [13]	valid_0's auc: 0.88448
# [14]	valid_0's auc: 0.886256
# [15]	valid_0's auc: 0.88823
# [16]	valid_0's auc: 0.889656
# [17]	valid_0's auc: 0.892217
# [18]	valid_0's auc: 0.892942
# [19]	valid_0's auc: 0.893532
# [20]	valid_0's auc: 0.894281
# [21]	valid_0's auc: 0.8957
# [22]	valid_0's auc: 0.896864
# [23]	valid_0's auc: 0.898245
# [24]	valid_0's auc: 0.898588
# [25]	valid_0's auc: 0.899434
# [26]	valid_0's auc: 0.900475
# [27]	valid_0's auc: 0.901957
# [28]	valid_0's auc: 0.902852
# [29]	valid_0's auc: 0.903684
# [30]	valid_0's auc: 0.904845
# [31]	valid_0's auc: 0.905419
# [32]	valid_0's auc: 0.905548
# [33]	valid_0's auc: 0.90605
# [34]	valid_0's auc: 0.906197
# [35]	valid_0's auc: 0.906706
# [36]	valid_0's auc: 0.907787
# [37]	valid_0's auc: 0.908574
# [38]	valid_0's auc: 0.90919
# [39]	valid_0's auc: 0.909788
# [40]	valid_0's auc: 0.910169
# [41]	valid_0's auc: 0.910807
# [42]	valid_0's auc: 0.911472
# [43]	valid_0's auc: 0.911807
# [44]	valid_0's auc: 0.912466
# [45]	valid_0's auc: 0.912758
# [46]	valid_0's auc: 0.913207
# [47]	valid_0's auc: 0.913543
# [48]	valid_0's auc: 0.914181
# [49]	valid_0's auc: 0.914864
# [50]	valid_0's auc: 0.91542
# [51]	valid_0's auc: 0.915793
# [52]	valid_0's auc: 0.916248
# [53]	valid_0's auc: 0.916652
# [54]	valid_0's auc: 0.916991
# [55]	valid_0's auc: 0.91726
# [56]	valid_0's auc: 0.917843
# [57]	valid_0's auc: 0.91819
# [58]	valid_0's auc: 0.918398
# [59]	valid_0's auc: 0.918803
# [60]	valid_0's auc: 0.919171
# [61]	valid_0's auc: 0.919317
# [62]	valid_0's auc: 0.91943
# [63]	valid_0's auc: 0.919921
# [64]	valid_0's auc: 0.920406
# [65]	valid_0's auc: 0.920602
# [66]	valid_0's auc: 0.921134
# [67]	valid_0's auc: 0.921433
# [68]	valid_0's auc: 0.92166
# [69]	valid_0's auc: 0.921979
# [70]	valid_0's auc: 0.922275
# [71]	valid_0's auc: 0.922602
# [72]	valid_0's auc: 0.922899
# [73]	valid_0's auc: 0.923121
# [74]	valid_0's auc: 0.923311
# [75]	valid_0's auc: 0.923572
# [76]	valid_0's auc: 0.923838
# [77]	valid_0's auc: 0.924134
# [78]	valid_0's auc: 0.924327
# [79]	valid_0's auc: 0.92454
# [80]	valid_0's auc: 0.92472
# [81]	valid_0's auc: 0.924843
# [82]	valid_0's auc: 0.924946
# [83]	valid_0's auc: 0.925296
# [84]	valid_0's auc: 0.925658
# [85]	valid_0's auc: 0.925913
# [86]	valid_0's auc: 0.926189
# [87]	valid_0's auc: 0.926168
# [88]	valid_0's auc: 0.926268
# [89]	valid_0's auc: 0.926407
# [90]	valid_0's auc: 0.926677
# [91]	valid_0's auc: 0.926678
# [92]	valid_0's auc: 0.926933
# [93]	valid_0's auc: 0.927022
# [94]	valid_0's auc: 0.927238
# [95]	valid_0's auc: 0.92734
# [96]	valid_0's auc: 0.927405
# [97]	valid_0's auc: 0.92766
# [98]	valid_0's auc: 0.92782
# [99]	valid_0's auc: 0.927811
# [100]	valid_0's auc: 0.92808
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.92808

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


# Define the parameters for LGBM and create the train and test datasets
params = {'learning_rate': 0.0655224975751405, 'max_depth': 8, 'min_child_samples': 15, 'num_leaves': 71, 'reg_alpha': 0.25341385191007193}
dtrain = lgb.Dataset(X_train, label=y_train)
dtest = lgb.Dataset(X_test, label=y_test)

# Train the model with early stopping and a validation set
num_round = 100
early_stopping_rounds = 50
model = lgb.train(params, dtrain, num_round, valid_sets=[dtest], early_stopping_rounds=early_stopping_rounds)

# Predict on the test set and calculate the accuracy score
y_pred = model.predict(X_test)
y_pred = [round(val) for val in y_pred]
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)
# Out:
# C:\Users\jiyeo\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.070020 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 82620
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 324
# [LightGBM] [Info] Start training from score 4.500000
# [1]	valid_0's l2: 8.12009
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's l2: 8.00317
# [3]	valid_0's l2: 7.89024
# [4]	valid_0's l2: 7.79181
# [5]	valid_0's l2: 7.70107
# [6]	valid_0's l2: 7.61446
# [7]	valid_0's l2: 7.53231
# [8]	valid_0's l2: 7.45535
# [9]	valid_0's l2: 7.37706
# [10]	valid_0's l2: 7.30829
# [11]	valid_0's l2: 7.23913
# [12]	valid_0's l2: 7.17351
# [13]	valid_0's l2: 7.11562
# [14]	valid_0's l2: 7.05867
# [15]	valid_0's l2: 7.00361
# [16]	valid_0's l2: 6.95216
# [17]	valid_0's l2: 6.90595
# [18]	valid_0's l2: 6.85684
# [19]	valid_0's l2: 6.80957
# [20]	valid_0's l2: 6.76751
# [21]	valid_0's l2: 6.72383
# [22]	valid_0's l2: 6.68472
# [23]	valid_0's l2: 6.64564
# [24]	valid_0's l2: 6.6052
# [25]	valid_0's l2: 6.56776
# [26]	valid_0's l2: 6.53065
# [27]	valid_0's l2: 6.49466
# [28]	valid_0's l2: 6.46426
# [29]	valid_0's l2: 6.42663
# [30]	valid_0's l2: 6.39594
# [31]	valid_0's l2: 6.36534
# [32]	valid_0's l2: 6.34357
# [33]	valid_0's l2: 6.31674
# [34]	valid_0's l2: 6.29218
# [35]	valid_0's l2: 6.26388
# [36]	valid_0's l2: 6.24219
# [37]	valid_0's l2: 6.21732
# [38]	valid_0's l2: 6.19549
# [39]	valid_0's l2: 6.17223
# [40]	valid_0's l2: 6.14954
# [41]	valid_0's l2: 6.12994
# [42]	valid_0's l2: 6.10878
# [43]	valid_0's l2: 6.08612
# [44]	valid_0's l2: 6.06297
# [45]	valid_0's l2: 6.04586
# [46]	valid_0's l2: 6.02676
# [47]	valid_0's l2: 6.00778
# [48]	valid_0's l2: 5.99133
# [49]	valid_0's l2: 5.97143
# [50]	valid_0's l2: 5.95297
# [51]	valid_0's l2: 5.93677
# [52]	valid_0's l2: 5.9233
# [53]	valid_0's l2: 5.90847
# [54]	valid_0's l2: 5.89586
# [55]	valid_0's l2: 5.87902
# [56]	valid_0's l2: 5.86525
# [57]	valid_0's l2: 5.85126
# [58]	valid_0's l2: 5.83628
# [59]	valid_0's l2: 5.82315
# [60]	valid_0's l2: 5.81295
# [61]	valid_0's l2: 5.79967
# [62]	valid_0's l2: 5.78773
# [63]	valid_0's l2: 5.77599
# [64]	valid_0's l2: 5.76551
# [65]	valid_0's l2: 5.75451
# [66]	valid_0's l2: 5.74412
# [67]	valid_0's l2: 5.73365
# [68]	valid_0's l2: 5.72322
# [69]	valid_0's l2: 5.71366
# [70]	valid_0's l2: 5.70416
# [71]	valid_0's l2: 5.69429
# [72]	valid_0's l2: 5.68466
# [73]	valid_0's l2: 5.67597
# [74]	valid_0's l2: 5.66619
# [75]	valid_0's l2: 5.65241
# [76]	valid_0's l2: 5.6446
# [77]	valid_0's l2: 5.63531
# [78]	valid_0's l2: 5.62275
# [79]	valid_0's l2: 5.61366
# [80]	valid_0's l2: 5.6033
# [81]	valid_0's l2: 5.59792
# [82]	valid_0's l2: 5.58652
# [83]	valid_0's l2: 5.57831
# [84]	valid_0's l2: 5.57069
# [85]	valid_0's l2: 5.56408
# [86]	valid_0's l2: 5.55592
# [87]	valid_0's l2: 5.54425
# [88]	valid_0's l2: 5.53893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's l2: 5.53158
# [90]	valid_0's l2: 5.52548
# [91]	valid_0's l2: 5.5181
# [92]	valid_0's l2: 5.51145
# [93]	valid_0's l2: 5.50455
# [94]	valid_0's l2: 5.49498
# [95]	valid_0's l2: 5.49106
# [96]	valid_0's l2: 5.48805
# [97]	valid_0's l2: 5.4823
# [98]	valid_0's l2: 5.47506
# [99]	valid_0's l2: 5.4696
# [100]	valid_0's l2: 5.46327
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's l2: 5.46327
# Accuracy: 0.1341
