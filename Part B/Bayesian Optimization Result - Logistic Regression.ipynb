# %% [markdown]
# # Bayesian Optimization Result for Logistic Regression

# %%
from functions import train_predict_ml, cross_validation, load_data
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from hyperopt import fmin, tpe, Trials, STATUS_OK
from hyperopt import hp
import lightgbm as lgb
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Train-test split

# %% [markdown]
# Ori-score:52.2600%
#
# CV-acc: 52.665%

# %%
train_predict_ml(lr_t1, data_train="../Data/train_hog.csv", data_test="../Data/test_hog.csv")
# Out:
# Accuracy Score:
# ...
# Train Accuracy Score  :  55.1800 %
# Test Accuracy Score   :  52.5000 %
# Training Time         :  112.3396
#
# Classification Report:
# ...
#               precision    recall  f1-score   support
#
#     Airplane       0.59      0.59      0.59      1000
#   Automobile       0.60      0.63      0.61      1000
#         Bird       0.45      0.40      0.42      1000
#          Cat       0.39      0.30      0.34      1000
#         Deer       0.45      0.46      0.46      1000
#          Dog       0.45      0.43      0.44      1000
#         Frog       0.52      0.65      0.58      1000
#        Horse       0.57      0.59      0.58      1000
#         Ship       0.54      0.56      0.55      1000
#        Truck       0.63      0.65      0.64      1000
#
#     accuracy                           0.53     10000
#    macro avg       0.52      0.53      0.52     10000
# weighted avg       0.52      0.53      0.52     10000
#
#
# Confusion Matrix:
# ...

# %% [markdown]
# ## Cross-validation

# %%
cross_validation(lr_t1, data_train="../Data/train_hog.csv")
# Out:
# Model Accuracies:
# Individual Accuracy: [0.5293 0.5337 0.5325 0.5301 0.5331]
# Mean: 0.53174
# Standard Deviation: 0.001726962651593821
# Training Time: 722.0982992649078
